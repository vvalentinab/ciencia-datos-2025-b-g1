# %% [markdown]
# # Autores
# 1. xyz
# 2. abd

# %% [markdown]
# # Propuesta de Solución
#
# ## Reto 1: Obtener el porcentaje de cantidad de roles por location. Mostrarlos en una gráfica
# total_roles = 0; //Corresponde a todo el dataset
# r1 = 0
# r2 = 0
# r3 = 0
# r4 = 0
# r5 = 0
# r6 = 0
# r7 = 0
# r8 = 0
# r9 = 0
# r10 = 0
# rBlanck = 0
#
#
# // Porcentajes
# p_r1 = 0
# p_r2 = 0
# p_r3 = 0
# p_r4 = 0
# p_r5 = 0
# p_r6 = 0
# p_r7 = 0
# p_r8 = 0
# p_r9 = 0
# p_r10 = 0
# p_rBlanck = 0
#
# // Proceso
# p_r1 = (r1/total_roles)*100
#
# grafícar resultado
# *** graficar desde p_r1 a p_rblank

# %%
import pandas as pd

df = pd.read_csv('/content/Software_Professional_Salaries.csv')
df.head()
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries Reported   Location
# 0                  3  Bangalore
# 1                  3  Bangalore
# 2                  3  Bangalore
# 3                  3  Bangalore
# 4                  3  Bangalore

# %%
# Store original location names and their counts in a dictionary
location_data = {}
for i, (location, count) in enumerate(location_counts.items()):
    variable_name = f"r{i+1}"
    location_data[variable_name] = {'original_name': location, 'count': count}
    # You can now access the counts using the new variable names
    # For example: location_data['r1']['count']

print("Location counts with new variable names:")
for var_name, data in location_data.items():
    print(f"{var_name} ({data['original_name']}): {data['count']}")
# Out:
# Location counts with new variable names:
# r1 (Bangalore): 8265
# r2 (Hyderabad): 4468
# r3 (New Delhi): 4176
# r4 (Chennai): 2458
# r5 (Pune): 2135
# r6 (Mumbai): 749
# r7 (Kolkata): 178
# r8 (Madhya Pradesh): 155
# r9 (Kerala): 108
# r10 (Jaipur): 82

# %%
# Calculate percentages for each location
percentage_data = {}
for var_name, data in location_data.items():
    percentage_variable_name = f"p_{var_name}"
    percentage = (data['count'] / total_roles) * 100
    percentage_data[percentage_variable_name] = percentage
    print(f"{percentage_variable_name} ({data['original_name']}): {percentage:.2f}%")

# You can now access the percentages using the new variable names
# For example: percentage_data['p_r1']
# Out:
# p_r1 (Bangalore): 36.29%
# p_r2 (Hyderabad): 19.62%
# p_r3 (New Delhi): 18.34%
# p_r4 (Chennai): 10.79%
# p_r5 (Pune): 9.37%
# p_r6 (Mumbai): 3.29%
# p_r7 (Kolkata): 0.78%
# p_r8 (Madhya Pradesh): 0.68%
# p_r9 (Kerala): 0.47%
# p_r10 (Jaipur): 0.36%

# %%
import matplotlib.pyplot as plt

# Prepare data for plotting
locations = [data['original_name'] for data in location_data.values()]
percentages = [percentage_data[f"p_{var_name}"] for var_name in location_data.keys()]

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(locations, percentages)
plt.xlabel("Location")
plt.ylabel("Percentage of Roles")
plt.title("Percentage of Roles by Location")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
