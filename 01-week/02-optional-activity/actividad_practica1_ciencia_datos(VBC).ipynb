# %% [markdown]
# # **Actividad práctica — Tema 1: Introducción a laCiencia de Datos**
#
# Autora: Valentina Bahamón Cordón

# %% [markdown]
# ## **1. Definición y evolución de la ciencia de datos**
#
# ### Línea de tiempo - Evolución de la Ciencia de Datos 📅
#
#
#
#
# ![timeline_Data_Science.png](data:image/png;base64,...)
#
#
# ### Importancia de la Evolución
#
#
# Esta evolución ha sido fundamental en el contexto tecnológico actual porque ha transformado la forma en que las organizaciones toman decisiones. Hemos pasado de análisis descriptivos básicos a sistemas predictivos y prescriptivos que pueden automatizar decisiones complejas en tiempo real. La integración de múltiples disciplinas (estadística, informática, dominio específico) ha permitido que las empresas no solo comprendan qué pasó, sino que predigan qué va a pasar y recomienden qué hacer al respecto. Esta evolución ha democratizado el acceso a insights avanzados, permitiendo que organizaciones de todos los tamaños puedan competir basándose en datos y no solo en intuición.

# %% [markdown]
# ## 2. Perfil y competencias del científico de datos
#
# ### ***Competencias Técnicas*** 👜💻
#
# *   Programación - Python, R, SQL, Scala para manipulación y análisis de datos
# *   Machine Learning - Algoritmos supervisados, no supervisados y de refuerzo
# *   Manejo de Bases de Datos - SQL, NoSQL, diseño de esquemas y optimización de consultas
# *   Herramientas de Cloud - AWS, GCP, Azure para escalabilidad y despliegue
# *   Visualización de Datos - Power BI, Tableau, matplotlib, ggplot para comunicar insights
#
#
# ### ***Competencias Blandas*** 😀👍
#
# *   Comunicación efectiva - Traducir hallazgos técnicos a lenguaje de negocio
# *   Pensamiento crítico - Cuestionar datos, metodologías y resultados
# *   Resolución de problemas - Descomponer problemas complejos en partes manejables
# *   Trabajo colaborativo - Integración con equipos multidisciplinarios
# *   Adaptabilidad - Flexibilidad ante nuevas tecnologías y metodologías
#
#
#
# ### ***Relación con Sectores***
#
# Estas competencias se complementan para resolver problemas específicos: **en salud**, la programación y ML permiten desarrollar modelos predictivos para diagnósticos tempranos, mientras que la comunicación efectiva es crucial para que médicos adopten estas herramientas. En **finanzas**, las habilidades técnicas detectan patrones de fraude en tiempo real, pero el pensamiento crítico evalúa falsos positivos que podrían bloquear transacciones legítimas. En **marketing**, la visualización de datos comunica insights de segmentación a equipos creativos, mientras que la colaboración integra hallazgos analíticos con estrategias de marca. En **gobierno**, la adaptabilidad permite trabajar con datos heterogéneos de múltiples fuentes, y la resolución de problemas aborda desafíos complejos como optimización de servicios públicos o análisis de políticas públicas.

# %% [markdown]
# ## **3. Diferencias entre estadística, minería de datos y ciencia de datos**
#
# | Aspecto | **Estadística** 📊 | **Minería de Datos** ⛏️ | **Ciencia de Datos** 🔬 |
# |---------|-------------------|------------------------|------------------------|
# | **Definición** | Análisis descriptivo e inferencial basado en fundamentos matemáticos rigurosos | Descubrimiento de patrones ocultos en grandes datasets mediante algoritmos | Integración de estadística, informática y conocimiento de dominio para extraer valor |
# | **Herramientas** | R, SPSS, SAS, Excel | Weka, RapidMiner, Orange, KNIME | Python, R, SQL, TensorFlow, Cloud platforms |
# | **Objetivos** | Probar hipótesis, estimar parámetros, hacer inferencias poblacionales | Encontrar patrones, clasificar, hacer clustering, reglas de asociación | Solucionar problemas de negocio end-to-end con datos |
# | **Ejemplos** | Encuestas, experimentos controlados, análisis de correlación | Análisis de canasta de compras, segmentación de clientes, detección de anomalías | Sistemas de recomendación, chatbots, optimización de precios dinámicos |
#
#
#
# ### 🔑 **Diferencia Clave**
#
#
# - **Estadística**: Base teórica y matemática
# - **Minería de Datos**: Enfoque algorítmico para encontrar patrones
# - **Ciencia de Datos**: Enfoque holístico que incluye programación, despliegue en producción y solución de problemas de negocio

# %% [markdown]
# ## 4. Ciclo de vida CRISP-DM
#
# ### Diagrama del Proceso
#
# ![FASES DE CRISP-DM.png](data:image/png;base64,...)
#
#
# ### Ejemplo: Análisis de Datos de Supermercado para Mejorar Promociones
#
# **1. Comprensión del Negocio**
# - Objetivo: Aumentar ventas 15% mediante promociones personalizadas
# - Problema: Promociones genéricas tienen baja tasa de conversión (2%)
# - KPIs: Tasa de conversión, ticket promedio, frecuencia de compra
#
# **2. Comprensión de los Datos**
# - Datos disponibles: transacciones (2 años), productos, clientes, promociones anteriores
# - Calidad: 95% completitud, algunos valores atípicos en precios
# - Volumen: 2 millones de transacciones, 50,000 clientes activos
#
# **3. Preparación de los Datos**
# - Limpieza: eliminar transacciones canceladas, corregir precios negativos
# - Transformación: crear variables de recencia, frecuencia, valor monetario (RFM)
# - Integración: unir datos de transacciones con información demográfica
#
# **4. Modelado**
# - Segmentación de clientes usando K-means
# - Modelo predictivo de propensión a compra (Random Forest)
# - Análisis de canasta de mercado para productos complementarios
#
# **5. Evaluación**
# - Modelo de segmentación: 4 grupos bien diferenciados
# - Predicción: 78% accuracy en propensión de compra
# - Validación con grupo control: 12% mejora vs promociones generales
#
# **6. Despliegue**
# - Dashboard para el equipo de marketing
# - API que envía recomendaciones diarias al sistema de CRM
# - Monitoreo continuo de performance del modelo
#
# **Diagrama de flujo de este ejemplo:**
#
# ```
#     ┌─────────────────────┐
#     │   COMPRENSIÓN DEL   │
#     │      NEGOCIO        |
#     | Aumentar ventas 15% │◄─────────┐
#     └──────────┬──────────┘          │
#                │                     │
#                ▼                     │
#     ┌─────────────────────┐          │
#     │   COMPRENSIÓN DE    │          │
#     │     LOS DATOS       |          |
#     |    Revisar datos    |          |
#     |     disponibles     │          │
#     └──────────┬──────────┘          │
#                │                     │
#                ▼                     │
#     ┌─────────────────────┐          │
#     │   PREPARACIÓN DE    │          │
#     │     LOS DATOS       |          |
#     | Limpiar, transformar|          |
#     |         y unir      │◄─────┐   │
#     └──────────┬──────────┘      │   │
#                │                 │   │
#                ▼                 │   │
#     ┌─────────────────────┐      │   │
#     │      MODELADO       |      |   |
#     |  Segmentar clientes |      |   |
#     |  y predecir compras │──────┘   │
#     └──────────┬──────────┘          │
#                │                     │
#                ▼                     │
#     ┌─────────────────────┐          │
#     │     EVALUACIÓN      |          |
#     |    Medir éxito      |          |
#     |  y validar modelo   │──────────┘
#     └──────────┬──────────┘
#                │
#                ▼
#     ┌─────────────────────┐
#     │     DESPLIEGUE      |
#     |   Dashboard, API    |
#     |     y monitoreo     │
#     └─────────────────────┘
# ```

# %% [markdown]
# ## 5. Casos de éxito y aplicaciones actuales
#
# ### Caso 1: Netflix - Sistema de Recomendaciones
#
# **El Problema Inicial**:
# Netflix enfrentaba el desafío de mantener a sus suscriptores comprometidos con el contenido disponible en su plataforma. Con miles de títulos disponibles, los usuarios experimentaban "parálisis de elección" y muchos abandonaban la plataforma por no encontrar contenido relevante. La empresa necesitaba una forma de personalizar la experiencia de cada usuario para aumentar el tiempo de visualización y reducir la tasa de cancelación.
#
# **Cómo se Aplicó la Ciencia de Datos**:
# Netflix implementó un sofisticado sistema de recomendaciones que utiliza múltiples algoritmos de machine learning. El sistema analiza el comportamiento de visualización de cada usuario (qué ve, cuándo pausa, qué omite, calificaciones), lo combina con metadatos de contenido (género, actores, director, año) y patrones de usuarios similares. Utilizan filtrado colaborativo, factorización matricial y redes neuronales profundas para generar recomendaciones personalizadas. Además, realizan pruebas A/B continuas para optimizar algoritmos y interfaces.
#
# **El Impacto Generado**:
# El sistema de recomendaciones de Netflix genera más del 80% de las horas de contenido visto en la plataforma. Esto ha resultado en una retención de clientes significativamente mayor, con tasas de cancelación menores al promedio de la industria. La empresa estima que su algoritmo de recomendaciones les ahorra más de $1 billón de dólares anuales al evitar cancelaciones. Además, les permite tomar decisiones informadas sobre qué contenido original producir, basándose en los patrones de consumo y preferencias identificadas.
#
# ### Caso 2: Waze - Optimización de Rutas en Tiempo Real
#
# **El Problema Inicial**:
# Los conductores urbanos enfrentaban constantemente problemas de tráfico, accidentes y rutas ineficientes que resultaban en pérdida de tiempo, combustible y frustración. Los sistemas de navegación tradicionales se basaban en datos estáticos y no consideraban condiciones de tráfico en tiempo real, construcciones temporales, o eventos inesperados que afectaban la movilidad urbana.
#
# **Cómo se Aplicó la Ciencia de Datos**:
# Waze desarrolló una plataforma que recolecta datos en tiempo real de millones de usuarios (GPS, velocidad, paradas, reportes manuales de usuarios). Utilizan algoritmos de machine learning para procesar esta información masiva y identificar patrones de tráfico, predecir congestionamientos y detectar incidentes. El sistema emplea algoritmos de optimización de rutas que consideran múltiples variables: distancia, tiempo estimado, condiciones de tráfico actuales e históricas, y preferencias del usuario. También implementan procesamiento de lenguaje natural para analizar reportes de usuarios sobre accidentes, policía o construcciones.
#
# **El Impacto Generado**:
# Waze ha logrado reducir el tiempo promedio de viaje de sus usuarios en un 12-20% comparado con rutas tradicionales. La aplicación cuenta con más de 140 millones de usuarios activos mensuales que contribuyen con datos, creando un efecto de red que mejora continuamente la precisión del sistema. Gobiernos y empresas utilizan los datos agregados de Waze para planificación urbana y optimización de infraestructura. Google adquirió la empresa por $1.15 billones de dólares, y su tecnología ahora también potencia Google Maps, impactando a miles de millones de usuarios globalmente.
