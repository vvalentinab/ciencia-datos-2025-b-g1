# %% [markdown]
# # Primer ejemplo en python
#
# * Saber si una persona es mayor o menor de edad.

# %%
edad = int(input("Digite la edad de la persona: "))

if edad > 0 and edad < 130:
  if edad >= 18:
    print("Mayor de edad")
  else:
    print("Menor de edad")
else:
  print("Edad incorrecta")
# Out:
# Digite la edad de la persona: 21
# Mayor de edad
