# %% [markdown]
# # **Actividad Práctica: Fundamentos de Big Data**
#
# Autora: Valentina Bahmón Cordón

# %% [markdown]
# ###  **1. Concepto de Big Data y sus 5V**
#
#
# *Definición de Big Data:*
# Big Data se refiere a conjuntos de datos de tamaño, complejidad y velocidad de generación tan grandes que superan la capacidad de procesamiento, almacenamiento y análisis de las herramientas tradicionales de gestión de datos. No se trata solo de la cantidad de información, sino de la combinación de características que requieren nuevas tecnologías, metodologías y enfoques para extraer valor y generar insights significativos que impulsen la toma de decisiones.

# %% [markdown]
# ***Esquema Visual de las 5V del Big Data***

# %% [markdown]
#                    🎯 VALOR 🎯
#                 ¿Qué insights obtenemos?
#                       ↗    ↖
#                      /      \
#         📊 VOLUMEN           ✅ VERACIDAD
#     ¿Cuántos datos?         ¿Son confiables?
#            ↗                     ↖
#           /                       \
#     ⚡ VELOCIDAD  ←────── 🔄 ────→  🎨 VARIEDAD
#   ¿Qué tan rápido?                ¿Qué formatos?

# %% [markdown]
# Y además adjunto la imagen(esquema) de lo que me enseño la certificación de IBM sobre Big Data:
# ![Big Data and 5V.png](data:image/png;base64,...)

# %% [markdown]
# ***Ejemplos Reales para cada V***
#
#
# 📊 VOLUMEN - Facebook
#
# Ejemplo: Facebook procesa más de 4 petabytes de datos diariamente
# Contexto: Incluye posts, fotos, videos, likes, comentarios, mensajes de más de 2.9 billones de usuarios activos mensualmente
#
#
# ⚡ VELOCIDAD - Sensores IoT en Automóviles Tesla
#
# Ejemplo: Los vehículos Tesla generan aproximadamente 25 GB de datos por hora de conducción
# Contexto: Datos de sensores, cámaras, GPS procesados en tiempo real para autopilot y actualizaciones de software
#
# 🎨 VARIEDAD - Hospital Clínico
#
# Ejemplo: Historias clínicas (estructurado), imágenes de resonancia magnética (no estructurado), datos de sensores de signos vitales (semiestructurado)
# Contexto: Integración de múltiples fuentes para diagnósticos precisos y medicina personalizada
#
# ✅ VERACIDAD - Redes Sociales durante Crisis
#
# Ejemplo: Durante desastres naturales, Twitter recibe millones de tweets, pero solo 15-20% contienen información verificable
# Contexto: Necesidad de filtrar noticias falsas, duplicados e información errónea para respuesta efectiva a emergencias
#
# 🎯 VALOR - Netflix Sistema de Recomendaciones
#
# Ejemplo: Netflix utiliza datos de visualización para generar más de $1 billón en ahorros anuales por retención de usuarios
# Contexto: Transforma patrones de consumo en recomendaciones que mantienen 80% del engagement de la plataforma

# %% [markdown]
# ###  **2. Diferencias entre datos estructurados, semiestructurados y no estructurados**
# | Aspecto | **Estructurados** 🏗️ | **Semiestructurados** 🔧 | **No Estructurados** 🎨 |
# |---------|---------------------|---------------------------|-------------------------|
# | **Definición** | Datos organizados en formato fijo con esquema predefinido (filas y columnas) | Datos con cierta organización mediante etiquetas, claves o metadatos, pero sin esquema rígido | Datos sin formato o estructura predefinida, carece de organización interna |
# | **Ejemplos** | • Bases de datos SQL<br>• Hojas de cálculo<br>• Transacciones bancarias<br>• Registros de ventas | • Archivos JSON/XML<br>• Logs de aplicaciones<br>• Datos de sensores IoT<br>• APIs REST responses | • Videos y fotos<br>• Correos electrónicos<br>• Documentos PDF<br>• Audio y podcasts<br>• Posts en redes sociales |
# | **Herramientas** | • MySQL, PostgreSQL<br>• Excel, Google Sheets<br>• SQL Server<br>• Oracle Database | • MongoDB, CouchDB<br>• Elasticsearch<br>• Apache Kafka<br>• Redis | • Hadoop HDFS<br>• Apache Spark<br>• OpenCV (imágenes)<br>• NLTK/spaCy (texto)<br>• TensorFlow/PyTorch |
# | **Ventajas** | • Consultas rápidas<br>• Integridad referencial<br>• Transacciones ACID | • Flexibilidad de esquema<br>• Fácil integración<br>• Adaptabilidad | • Rica información<br>• Insights profundos<br>• Diversidad de fuentes |
# | **Desafíos** | • Esquema rígido<br>• Escalabilidad vertical | • Validación compleja<br>• Consistencia variable | • Procesamiento costoso<br>• Requiere IA/ML<br>• Almacenamiento masivo |

# %% [markdown]
# ###🔥 **Mayor Uso en Big Data**
# Los **datos no estructurados** representan aproximadamente el **80-90%** de todos los datos generados globalmente, siendo los más relevantes para Big Data debido a su volumen masivo y la riqueza de insights que pueden proporcionar.

# %% [markdown]
# ## 3. Bases de datos relacionales vs. bases de datos distribuidas

# %% [markdown]
# ```
#     BASES DE DATOS RELACIONALES              BASES DE DATOS DISTRIBUIDAS
#            (Tradicionales)                         (Big Data / NoSQL)
#
#     ┌─────────────────────────┐              ┌─────────────────────────┐
#     │     MODELO DE DATOS     │              │     MODELO DE DATOS     │
#     │                         │              │                         │
#     │  ┌─────┬─────┬─────┐    │              │  ┌─────────────────┐    │
#     │  │ ID  │Name │ Age │    │              │  │  {                │    │
#     │  ├─────┼─────┼─────┤    │              │  │   "_id": "123",   │    │
#     │  │  1  │Juan │ 25  │    │              │  │   "name": "Juan", │    │
#     │  │  2  │Ana  │ 30  │    │              │  │   "age": 25,      │    │
#     │  └─────┴─────┴─────┘    │              │  │   "skills": [...] │    │
#     │   Esquema Fijo/Rígido    │              │  │  }                │    │
#     └─────────────────────────┘              └─────────────────────────┘
#                                                  Esquema Flexible
#     ┌─────────────────────────┐              ┌─────────────────────────┐
#     │     ESCALABILIDAD       │              │     ESCALABILIDAD       │
#     │                         │              │                         │
#     │        VERTICAL         │              │       HORIZONTAL        │
#     │          ↑               │              │   ┌───┐ ┌───┐ ┌───┐     │
#     │      ┌───────┐          │              │   │ N1│ │ N2│ │ N3│     │
#     │      │ MORE  │          │              │   └───┘ └───┘ └───┘     │
#     │      │ POWER │          │              │   ┌───┐ ┌───┐ ┌───┐     │
#     │      └───────┘          │              │   │ N4│ │ N5│ │ N6│     │
#     │     (Más hardware)       │              │   └───┘ └───┘ └───┘     │
#     └─────────────────────────┘              └─────────────────────────┘
#                                                  (Más nodos)
#     ┌─────────────────────────┐              ┌─────────────────────────┐
#     │     CONSISTENCIA        │              │     CONSISTENCIA        │
#     │                         │              │                         │
#     │     ACID COMPLETO       │              │   EVENTUAL (BASE)       │
#     │   ✅ Atomicidad          │              │   ⏰ Eventually Consistent│
#     │   ✅ Consistencia        │              │   ⚡ High Availability   │
#     │   ✅ Aislamiento         │              │   📊 Partition Tolerance │
#     │   ✅ Durabilidad         │              │                         │
#     └─────────────────────────┘              └─────────────────────────┘
#
#     ┌─────────────────────────┐              ┌─────────────────────────┐
#     │      CASOS DE USO       │              │      CASOS DE USO       │
#     │                         │              │                         │
#     │ • Sistemas bancarios    │              │ • Redes sociales        │
#     │ • ERP empresariales     │              │ • IoT y sensores        │
#     │ • Contabilidad          │              │ • Catálogos de e-commerce│
#     │ • Inventarios           │              │ • Logs y analytics      │
#     │ • Nóminas               │              │ • Sistemas de recomendación│
#     └─────────────────────────┘              └─────────────────────────┘
# ```

# %% [markdown]
# ### Ejemplos de Implementación
#
# **Bases de Datos Relacionales:**
# - **PostgreSQL**: Usado por Instagram para manejar metadatos de fotos y relaciones entre usuarios
# - **MySQL**: Utilizado por Facebook para almacenar información estructurada de perfiles y relaciones
#
# **Bases de Datos Distribuidas:**
# - **Cassandra**: Utilizada por Netflix para almacenar datos de visualización y preferencias de 200+ millones de usuarios
# - **MongoDB**: Empleada por Forbes para gestionar contenido editorial y análisis de engagement en tiempo real>

# %% [markdown]
# ## 4. Introducción a la computación distribuida
#
# ### Definición y Importancia
#
# La computación distribuida es un paradigma donde múltiples computadoras conectadas en red trabajan de manera coordinada para resolver un problema común, dividiendo el trabajo en tareas más pequeñas que se ejecutan simultáneamente en diferentes nodos. Es clave para Big Data porque permite procesar volúmenes masivos de información que serían imposibles de manejar en un solo servidor, proporcionando escalabilidad horizontal, tolerancia a fallos y procesamiento paralelo que reduce significativamente los tiempos de ejecución.
#
# ### Tecnologías Principales
#
# **🐘 Apache Hadoop**
# Hadoop revolucionó el Big Data introduciendo HDFS (sistema de archivos distribuido) y MapReduce para procesamiento en lotes. Su filosofía "mover el código a los datos" permite procesar petabytes de información distribuyendo archivos en múltiples nodos y ejecutando computación donde residen los datos. Es ideal para análisis históricos, ETL masivos y procesamiento batch de grandes volúmenes de datos estructurados y no estructurados.
#
# **⚡ Apache Spark**
# Spark mejoró el paradigma de Hadoop procesando datos en memoria RAM en lugar de disco, siendo hasta 100x más rápido para algoritmos iterativos. Su arquitectura DAG (Directed Acyclic Graph) optimiza automáticamente la ejecución de tareas, mientras que su API unificada permite procesamiento batch, streaming, machine learning y SQL en una sola plataforma, convirtiéndolo en la herramienta preferida para analítica avanzada y modelos predictivos en tiempo real.

# %% [markdown]
# ## 5. Retos y oportunidades del Big Data en la industria

# %% [markdown]
# ### Sector Seleccionado: **SALUD** 🏥
#
# ### Retos del Big Data en Salud
#
# **🔒 Reto 1: Privacidad y Cumplimiento Normativo**
# La gestión de datos médicos enfrenta estrictas regulaciones como HIPAA (Estados Unidos), GDPR (Europa) y leyes locales de protección de datos. Los hospitales deben garantizar anonimización completa, control de acceso granular y trazabilidad de quién accede a qué información. La interoperabilidad entre sistemas legacy y nuevas plataformas Big Data complejiza el cumplimiento, requiriendo auditorías constantes y protocolos de seguridad multicapa que pueden ralentizar la implementación de soluciones innovadoras.
#
# **📊 Reto 2: Calidad y Estandarización de Datos**
# Los datos clínicos provienen de múltiples fuentes heterogéneas: historias clínicas electrónicas, dispositivos médicos, laboratorios, imágenes diagnósticas, wearables, cada uno con formatos, estándares y niveles de calidad diferentes. La falta de estandarización global (HL7, FHIR, ICD-10) genera silos de información, datos inconsistentes y dificultades para crear datasets robustos que alimenten modelos de IA confiables para diagnósticos y tratamientos.
#
# ### Oportunidades del Big Data en Salud
#
# **🎯 Oportunidad 1: Medicina Personalizada y Predictiva**
# Big Data permite analizar genomas completos, historiales médicos, estilos de vida y datos ambientales para crear perfiles de riesgo individualizados. Los algoritmos de machine learning pueden predecir enfermedades años antes de que se manifiesten, personalizar tratamientos según la genética del paciente, optimizar dosis de medicamentos y reducir efectos adversos. Esto revoluciona la medicina preventiva, mejora outcomes y reduce costos del sistema de salud.
#
# **🚀 Oportunidad 2: Optimización Operacional y Recursos**
# El análisis de flujos de pacientes, ocupación de camas, tiempos de espera, uso de equipos médicos y patrones de demanda permite optimizar la asignación de recursos hospitalarios. Modelos predictivos pueden anticipar picos de demanda en emergencias, optimizar programación de cirugías, reducir tiempos de espera y mejorar la experiencia del paciente mientras se maximiza la eficiencia operacional y se reducen costos administrativos.
#
# ### Caso de Uso Innovador: **Smart Hospital con IA Predictiva**
#
# **Propuesta**: Implementar una plataforma integrada de Big Data que combine sensores IoT, wearables de pacientes, historiales clínicos, imágenes médicas y datos ambientales para crear un "hospital inteligente" que predice y previene complicaciones médicas en tiempo real.
#
# **Funcionamiento**:
# - **Sensores IoT** monitoriean signos vitales, movimiento de pacientes, calidad del aire y ocupación de espacios
# - **Algoritmos de ML** analizan patrones para predecir deterioro clínico, riesgo de infecciones nosocomiales y caídas de pacientes
# - **Dashboard en tiempo real** alerta al personal médico sobre pacientes de alto riesgo antes de que se manifiesten complicaciones
# - **Optimización automática** de rutas de personal, asignación de recursos y programación de intervenciones preventivas
#
# **Impacto Esperado**:
# - Reducción del 40% en complicaciones prevenibles
# - Disminución del 25% en tiempos de estadía hospitalaria
# - Mejora del 60% en satisfacción del paciente
# - Ahorro del 30% en costos operacionales por optimización de recursos y reducción de readmisiones

# %% [markdown]
# ## Conclusión
#
# Los fundamentos de Big Data representan una revolución tecnológica que va más allá del simple manejo de grandes volúmenes de información. Las 5V (Volumen, Velocidad, Variedad, Veracidad y Valor) establecen el marco conceptual para entender por qué necesitamos nuevas aproximaciones tecnológicas. La evolución desde bases de datos relacionales hacia sistemas distribuidos responde a necesidades reales de escalabilidad y flexibilidad que los sectores modernos demandan.
#
# La computación distribuida, ejemplificada por tecnologías como Hadoop y Spark, democratiza el acceso a capacidades de procesamiento antes reservadas solo para grandes corporaciones. Sin embargo, como muestra el análisis del sector salud, Big Data no solo trae oportunidades sino también retos significativos de privacidad, calidad de datos y integración que deben abordarse estratégicamente.
#
# El futuro del Big Data no está en la tecnología per se, sino en su capacidad para generar valor real y transformar industrias completas, como demuestra el caso del Smart Hospital, donde la convergencia de IoT, IA y Big Data puede salvar vidas y optimizar recursos de manera simultánea.
